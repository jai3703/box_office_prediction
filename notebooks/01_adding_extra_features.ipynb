# %% [markdown]
# pull data from basic_features.parquet

# %%
import pandas as pd
import helpers

# %%
basic_movie_info = pd.read_parquet('basic_features.parquet')

# %%
basic_movie_info.head()
# Out:
#      budget      id    imdb_id  popularity    revenue  \
# 0  10400000  360814  tt5074352      22.057  311000000
# 1   6087315  132316  tt2176013       9.961  256884693
# 2   7700000   61202  tt1562872      22.366  160000000
# 3  13000000  348892  tt3863552      16.974  150000000
# 4    286284  441889  tt6108090      12.123  137416709
#
#                       title release_date  cast_popularity  crew_popularity  \
# 0                    Dangal   2016-12-21           68.289           72.850
# 1          Jab Tak Hai Jaan   2012-11-13           76.745           35.234
# 2  Zindagi Na Milegi Dobara   2011-07-15           77.934           91.112
# 3         Bajrangi Bhaijaan   2015-07-17           72.644          114.852
# 4          Secret Superstar   2017-10-19           33.289           35.091
#
#   star_present
# 0          Yes
# 1          Yes
# 2          Yes
# 3          Yes
# 4          Yes

# %%
pd.DataFrame([helpers.get_features_movie(360814)]
             )
# Out:
#      budget      id    imdb_id  popularity release_date    revenue   title  \
# 0  10400000  360814  tt5074352      26.566   2016-12-21  311000000  Dangal
#
#    cast_popularity  crew_popularity star_present
# 0           96.753           79.887          yes

# %%
import locale
from math import log10

def sexify(value):
    """
    formats the float value to indian money format
    :param value: 
    :return: 
    """

    MAP = {
        0: '',
        1: '',
        2: '',
        3: 'Thousand',
        4: 'Thousand',
        5: 'Lakh',
        6: 'Lakh',
        7: 'Crore',
        8: 'Crore',
    }

    power = int(log10(abs(value)))
    locale.setlocale(locale.LC_ALL, 'en_IN')
    if power <= 8:

        humanized = locale.format('%d', value, grouping=True)
        rounded = humanized[:4].replace(',', '.')
        s = rounded + ' ' + MAP[power]
        if (rounded != '1.00'): s = s + 's'
    else:
        value = value / 10000000
        humanized = locale.format('%d', value, grouping=True)
        s = humanized + ' ' + 'Crores'

    return s


sexified = sexify(10970300.00)
print(sexified)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[3], line 39
#      34         s = humanized + ' ' + 'Crores'
#      36     return s
# ---> 39 sexified = sexify(10970300.00)
#      40 print(sexified)
#
# Cell In[3], line 24, in sexify(value)
#      11 MAP = {
#      12     0: '',
#      13     1: '',
#    (...)
#      20     8: 'Crore',
#      21 }
#      23 power = int(log10(abs(value)))
# ---> 24 locale.setlocale(locale.LC_ALL, 'en_IN')
#      25 if power <= 8:
#      27     humanized = locale.format('%d', value, grouping=True)
#
# File ~/.python/current/lib/python3.10/locale.py:620, in setlocale(category, locale)
#     617 if locale and not isinstance(locale, _builtin_str):
#     618     # convert to string
#     619     locale = normalize(_build_localename(locale))
# --> 620 return _setlocale(category, locale)
#
# Error: unsupported locale setting
